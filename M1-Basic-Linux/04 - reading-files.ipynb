# %% [markdown]
# #### Reading Files
#
# ---
#
# AWS EC2 Instance

# %% [markdown]
# Using the cat command, display the contents of the fixGenerator.sh script to the screen.

# %%
cat fixGenerator.sh
# Out:
# #!/bin/bash
#
# #############################################
# # v1.1 of script by Su Morton
# # date 6/5/2020
# #############################################
#
# #writing a script to generate a fix log
#
# # First step is to generate the logon messages
#
# TODAY=$(date "+%Y-%m-%d")
#
# # open the log file
# LOGFILENAME="fixlog"$(date "+%Y%m%d%H%M%S")".log"
#
# touch $LOGFILENAME
#
# # Need to setup some of the variables we will need
#
# CLIENT="MTHREE"
# BROKER="MS"
#
# HEARTBEAT=""
# HEARTBEATRESPONSE=""
#
# CLIENTSEQNUMBER=1
# BROKERSEQNUMBER=1
#
# CURRENTTIME=$(date "+%Y-%m-%d-%T")
#
# # initial login messages on the session
#
# INITIALLOGON="8=FIX4.4; 35=A; 34=$CLIENTSEQNUMBER; 49=$CLIENT; 56=$BROKER; 52=$CURRENTTIME; 108=30; 10=0015;"
# INITIALLOGONACK="8=FIX4.4; 35=A; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 108=30; 10=0016;"
#
# echo $INITIALLOGON >>$LOGFILENAME
# echo $INITIALLOGONACK >>$LOGFILENAME
#
# # now we will put some heartbeat messages in the log before trading starts - we will make the number of heart beat messages configurable
# # To be authentic the sleep variable should be set to 30 in here
#
# TOTALHEARTBEATS=50
#
# until [ $CLIENTSEQNUMBER -gt $TOTALHEARTBEATS ]; do
#     let "CLIENTSEQNUMBER++"
#     let "BROKERSEQNUMBER++"
#     CURRENTTIME=$(date "+%Y-%m-%d-%T")
#
#     INITIALHEARTBEAT="8=FIX4.4; 35=0; 34=$CLIENTSEQNUMBER; 49=$CLIENT; 56=$BROKER; 52=$CURRENTTIME; 108=30; 10=0015;"
#     INITIALHEARTBEATACK="8=FIX4.4; 35=0; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 108=30; 10=0015;"
#     sleep 2
#
#     echo $INITIALHEARTBEAT >>$LOGFILENAME
#     echo $INITIALHEARTBEATACK >>$LOGFILENAME
#
# done
#
# #now we will look to setup some trading messages
#
# Stocks=('AAPL' 'MSFT' 'AMZN' 'FB' 'GOOG' 'GOOGL' 'INTC' 'PEP' 'NFLX' 'CSCO' 'AMGN' 'PYPL' 'TSLA' 'TXN' 'AVGO' 'GILD' 'SBUX' 'QCOM' 'TMUS' 'MDLZ' 'BAC' 'DDD' 'MMM' 'WBAI' 'WUBA' 'EGHT' 'AHC' 'AOS' 'ATEN' 'AIR' 'AAN' 'ABB' 'ABT' 'ABBV' 'ANF' 'ABM' 'AAPL' 'PEP')
# Prices=('1276.37' '59.89' '133.47' '430.62' '42.05' '289.20' '339.13' '36.21' '306.71' '233.73' '116.62' '723.61' '503.77' '112.46' '262.99' '82.91' '75.71' '75.47' '90.74' '52.26' '22.03' '8.01' '146.98' '4.10' '51.41' '17.03' '1.40' '40.38' '6.45' '16.31' '25.68' '17.42' '94.04' '83.60' '9.10' '31.64' '284.65' '45.43')
#
# CURRENTSTOCK=""
# CURRENTPRICE=""
# ORDERID=""
# QTY=""
# TOTALNEWORDERS=$(echo "${#Stocks[@]}")
# i=0
# until [ $i -gt $TOTALNEWORDERS ]; do
#     CURRENTSTOCK="$(echo ${Stocks[$i]})"
#     CURRENTTIME=$(date "+%Y-%m-%d-%T")
#     QTY=""
#     SIDE=1
#     CURRENTPRICE="$(echo ${Prices[$i]})"
#     ORDERID="algo"$(date "+%Y%m%d%H%M%S")
#     SIDE="$(echo $((1 + RANDOM % 2)))"
#     QTY="$(echo $(($RANDOM + 10)))"
#
#     let "CLIENTSEQNUMBER++"
#
#     NEWORDER="8=FIX4.4; 35=D; 34=$CLIENTSEQNUMBER; 49=$CLIENT; 56=$BROKER;  52=$CURRENTTIME; 55=$CURRENTSTOCK; 40=2; 38=$QTY; 21=2; 11=$ORDERID; 60=$CURRENTTIME; 54=$SIDE; 44=$CURRENTPRICE; 10=0252;"
#
#     echo $NEWORDER >>$LOGFILENAME
#
#     #set up the qty variables so we can acknowledge the message
#     LASTTRDQTY=0
#     LASTTRDVOL=0
#     EXECID="exec"$(date "+%Y%m%d%H%M%S")
#     CUMQTY=0
#     let "BROKERSEQNUMBER++"
#
#     NEWORDERACK="8=FIX4.4; 35=8; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 55=$CURRENTSTOCK; 40=2; 11=$ORDERID; 31=$CURRENTPRICE; 150=0; 39=0; 54=$SIDE; 44=$CURRENTPRICE; 32=$LASTTRDVOL; 17=$EXECID; 38=$QTY; 60=$CURRENTTIME; 6=$LASTTRDQTY; 14=$CUMQTY; 37=$ORDERID; 10=200;"
#
#     echo $NEWORDERACK >>$LOGFILENAME
#
#     #need to setup the partial fills
#     NUMBEROFFILLS=1
#     NUMBEROFFILLS="$(echo $((1 + RANDOM % 5)))"
#     x=0
#
#     LASTTRDQTY="$(echo $(($QTY / $NUMBEROFFILLS)))"
#     QTYREMAINING=0
#     QTYREMAINING="$(echo $(($QTY - $LASTTRDQTY)))"
#     NUMBEROFPARTIALFILLS="$(echo $(($NUMBEROFFILLS - 1)))"
#     FILLTEST=0
#
#     until [ $x -eq $NUMBEROFPARTIALFILLS ]; do
#
#         #now to chose if to fill or cancel
#
#         CANCELTEST="$(echo $((1 + RANDOM % 2)))"
#         FILLTEST=0
#
#         if [ $CANCELTEST -eq 1 ]; then
#             EXECID="exec"$(date "+%Y%m%d%H%M%S")
#             CURRENTTIME=$(date "+%Y-%m-%d-%T")
#             CUMQTY="$(echo $(($CUMQTY + $LASTTRDQTY)))"
#             let "BROKERSEQNUMBER++"
#
#             PARTIALFILL="8=FIX4.4; 35=8; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 55=$CURRENTSTOCK; 40=2; 11=$ORDERID; 31=$CURRENTPRICE; 150=1; 39=1; 54=$SIDE; 44=$CURRENTPRICE; 32=$LASTTRDQTY; 17=$EXECID; 38=$QTY; 60=$CURRENTTIME; 6=$CURRENTPRICE; 14=$CUMQTY; 37=$ORDERID; 10=240;"
#
#             echo $PARTIALFILL >>$LOGFILENAME
#
#             ((x = x + 1))
#
#             QTYREMAINING="$(echo $(($QTYREMAINING - $LASTTRDQTY)))"
#             FILLTEST=0
#             sleep 1
#
#         else
#
#             CURRENTTIME=$(date "+%Y-%m-%d-%T")
#             CANCELORDERID="C_"$(echo $ORDERID)
#             CANCELREQUEST="8=FIX4.4; 35=F; 34=$CLIENTSEQNUMBER; 49=$CLIENT; 56=$BROKER;  52=$CURRENTTIME; 41=$ORDERID; 55=$CURRENTSTOCK; 38=$QTY; 11=$CANCELORDERID; 60=$CURRENTTIME; 10=060;  "
#             echo $CANCELREQUEST >>$LOGFILENAME
#             let "CLIENTSEQNUMBER++"
#
#             EXECID="exec"$(date "+%Y%m%d%H%M%S")
#             CURRENTTIME=$(date "+%Y-%m-%d-%T")
#
#             PENDINGCANCEL="8=FIX4.4; 35=8; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 55=$CURRENTSTOCK; 11=$CANCELORDERID; 31=0; 150=6; 39=6; 54=$SIDE; 44=$CURRENTPRICE; 17=$EXECID; 32=0; 41=$ORDERID; 38=$QTY; 60=$CURRENTTIME; 6=0.0; 14=$CUMQTY; 37=$ORDERID; 10=252; "
#             echo $PENDINGCANCEL >>$LOGFILENAME
#             let "BROKERSEQNUMBER++"
#
#             EXECID="exec"$(date "+%Y%m%d%H%M%S")
#             CURRENTTIME=$(date "+%Y-%m-%d-%T")
#
#             CANCELACK="8=FIX4.4; 35=8; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 151=$QTYREMAINING; 55=$CURRENTSTOCK; 11=$CANCELORDERID; 31=0; 150=4; 39=4; 54=$SIDE; 17=$EXECID; 32=0;  41=$ORDERID; 38=$QTY; 60=$CURRENTTIME;  6=0.0; 14=$CUMQTY; 37=$ORDERID; 10=252;"
#
#             echo $CANCELACK >>$LOGFILENAME
#             let "BROKERSEQNUMBER++"
#             FILLTEST=1
#             x=$NUMBEROFPARTIALFILLS
#             sleep 1
#
#         fi
#
#     done
#     #if qty remaining is not = 0 then you need to do one more fill
#
#     ((i = i + 1))
#     sleep 1
#
#     #Now we need to send out the fully filled message if we need it
#     if [ $FILLTEST -eq 0 ]; then
#         EXECID="exec"$(date "+%Y%m%d%H%M%S")
#         CURRENTTIME=$(date "+%Y-%m-%d-%T")
#
#         QTYREMAINING="$(echo $(($QTY - $CUMQTY)))"
#         let "BROKERSEQNUMBER++"
#
#         FULLYFILLED="8=FIX4.4; 35=8; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 55=$CURRENTSTOCK; 40=2; 11=$ORDERID; 31=$CURRENTPRICE; 150=2; 39=2; 54=$SIDE; 44=$CURRENTPRICE; 32=$QTYREMAINING; 17=$EXECID; 38=$QTY; 60=$CURRENTTIME; 6=$CURRENTPRICE; 14=$QTY; 37=$ORDERID; 10=246;"
#
#         echo $FULLYFILLED >>$LOGFILENAME
#     fi
#
# done

# %% [markdown]
# Use the cat command to display the contents of the script you ran to the screen but with line numbers.

# %%
cat -n fixGenerator.sh
# Out:
#      1	#!/bin/bash
#      2
#      3	#############################################
#      4	# v1.1 of script by Su Morton
#      5	# date 6/5/2020
#      6	#############################################
#      7
#      8	#writing a script to generate a fix log
#      9
#     10	# First step is to generate the logon messages
#     11
#     12	TODAY=$(date "+%Y-%m-%d")
#     13
#     14	# open the log file
#     15	LOGFILENAME="fixlog"$(date "+%Y%m%d%H%M%S")".log"
#     16
#     17	touch $LOGFILENAME
#     18
#     19	# Need to setup some of the variables we will need
#     20
#     21	CLIENT="MTHREE"
#     22	BROKER="MS"
#     23
#     24	HEARTBEAT=""
#     25	HEARTBEATRESPONSE=""
#     26
#     27	CLIENTSEQNUMBER=1
#     28	BROKERSEQNUMBER=1
#     29
#     30	CURRENTTIME=$(date "+%Y-%m-%d-%T")
#     31
#     32	# initial login messages on the session
#     33
#     34	INITIALLOGON="8=FIX4.4; 35=A; 34=$CLIENTSEQNUMBER; 49=$CLIENT; 56=$BROKER; 52=$CURRENTTIME; 108=30; 10=0015;"
#     35	INITIALLOGONACK="8=FIX4.4; 35=A; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 108=30; 10=0016;"
#     36
#     37	echo $INITIALLOGON >>$LOGFILENAME
#     38	echo $INITIALLOGONACK >>$LOGFILENAME
#     39
#     40	# now we will put some heartbeat messages in the log before trading starts - we will make the number of heart beat messages configurable
#     41	# To be authentic the sleep variable should be set to 30 in here
#     42
#     43	TOTALHEARTBEATS=50
#     44
#     45	until [ $CLIENTSEQNUMBER -gt $TOTALHEARTBEATS ]; do
#     46	    let "CLIENTSEQNUMBER++"
#     47	    let "BROKERSEQNUMBER++"
#     48	    CURRENTTIME=$(date "+%Y-%m-%d-%T")
#     49
#     50	    INITIALHEARTBEAT="8=FIX4.4; 35=0; 34=$CLIENTSEQNUMBER; 49=$CLIENT; 56=$BROKER; 52=$CURRENTTIME; 108=30; 10=0015;"
#     51	    INITIALHEARTBEATACK="8=FIX4.4; 35=0; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 108=30; 10=0015;"
#     52	    sleep 2
#     53
#     54	    echo $INITIALHEARTBEAT >>$LOGFILENAME
#     55	    echo $INITIALHEARTBEATACK >>$LOGFILENAME
#     56
#     57	done
#     58
#     59	#now we will look to setup some trading messages
#     60
#     61	Stocks=('AAPL' 'MSFT' 'AMZN' 'FB' 'GOOG' 'GOOGL' 'INTC' 'PEP' 'NFLX' 'CSCO' 'AMGN' 'PYPL' 'TSLA' 'TXN' 'AVGO' 'GILD' 'SBUX' 'QCOM' 'TMUS' 'MDLZ' 'BAC' 'DDD' 'MMM' 'WBAI' 'WUBA' 'EGHT' 'AHC' 'AOS' 'ATEN' 'AIR' 'AAN' 'ABB' 'ABT' 'ABBV' 'ANF' 'ABM' 'AAPL' 'PEP')
#     62	Prices=('1276.37' '59.89' '133.47' '430.62' '42.05' '289.20' '339.13' '36.21' '306.71' '233.73' '116.62' '723.61' '503.77' '112.46' '262.99' '82.91' '75.71' '75.47' '90.74' '52.26' '22.03' '8.01' '146.98' '4.10' '51.41' '17.03' '1.40' '40.38' '6.45' '16.31' '25.68' '17.42' '94.04' '83.60' '9.10' '31.64' '284.65' '45.43')
#     63
#     64	CURRENTSTOCK=""
#     65	CURRENTPRICE=""
#     66	ORDERID=""
#     67	QTY=""
#     68	TOTALNEWORDERS=$(echo "${#Stocks[@]}")
#     69	i=0
#     70	until [ $i -gt $TOTALNEWORDERS ]; do
#     71	    CURRENTSTOCK="$(echo ${Stocks[$i]})"
#     72	    CURRENTTIME=$(date "+%Y-%m-%d-%T")
#     73	    QTY=""
#     74	    SIDE=1
#     75	    CURRENTPRICE="$(echo ${Prices[$i]})"
#     76	    ORDERID="algo"$(date "+%Y%m%d%H%M%S")
#     77	    SIDE="$(echo $((1 + RANDOM % 2)))"
#     78	    QTY="$(echo $(($RANDOM + 10)))"
#     79
#     80	    let "CLIENTSEQNUMBER++"
#     81
#     82	    NEWORDER="8=FIX4.4; 35=D; 34=$CLIENTSEQNUMBER; 49=$CLIENT; 56=$BROKER;  52=$CURRENTTIME; 55=$CURRENTSTOCK; 40=2; 38=$QTY; 21=2; 11=$ORDERID; 60=$CURRENTTIME; 54=$SIDE; 44=$CURRENTPRICE; 10=0252;"
#     83
#     84	    echo $NEWORDER >>$LOGFILENAME
#     85
#     86	    #set up the qty variables so we can acknowledge the message
#     87	    LASTTRDQTY=0
#     88	    LASTTRDVOL=0
#     89	    EXECID="exec"$(date "+%Y%m%d%H%M%S")
#     90	    CUMQTY=0
#     91	    let "BROKERSEQNUMBER++"
#     92
#     93	    NEWORDERACK="8=FIX4.4; 35=8; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 55=$CURRENTSTOCK; 40=2; 11=$ORDERID; 31=$CURRENTPRICE; 150=0; 39=0; 54=$SIDE; 44=$CURRENTPRICE; 32=$LASTTRDVOL; 17=$EXECID; 38=$QTY; 60=$CURRENTTIME; 6=$LASTTRDQTY; 14=$CUMQTY; 37=$ORDERID; 10=200;"
#     94
#     95	    echo $NEWORDERACK >>$LOGFILENAME
#     96
#     97	    #need to setup the partial fills
#     98	    NUMBEROFFILLS=1
#     99	    NUMBEROFFILLS="$(echo $((1 + RANDOM % 5)))"
#    100	    x=0
#    101
#    102	    LASTTRDQTY="$(echo $(($QTY / $NUMBEROFFILLS)))"
#    103	    QTYREMAINING=0
#    104	    QTYREMAINING="$(echo $(($QTY - $LASTTRDQTY)))"
#    105	    NUMBEROFPARTIALFILLS="$(echo $(($NUMBEROFFILLS - 1)))"
#    106	    FILLTEST=0
#    107
#    108	    until [ $x -eq $NUMBEROFPARTIALFILLS ]; do
#    109
#    110	        #now to chose if to fill or cancel
#    111
#    112	        CANCELTEST="$(echo $((1 + RANDOM % 2)))"
#    113	        FILLTEST=0
#    114
#    115	        if [ $CANCELTEST -eq 1 ]; then
#    116	            EXECID="exec"$(date "+%Y%m%d%H%M%S")
#    117	            CURRENTTIME=$(date "+%Y-%m-%d-%T")
#    118	            CUMQTY="$(echo $(($CUMQTY + $LASTTRDQTY)))"
#    119	            let "BROKERSEQNUMBER++"
#    120
#    121	            PARTIALFILL="8=FIX4.4; 35=8; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 55=$CURRENTSTOCK; 40=2; 11=$ORDERID; 31=$CURRENTPRICE; 150=1; 39=1; 54=$SIDE; 44=$CURRENTPRICE; 32=$LASTTRDQTY; 17=$EXECID; 38=$QTY; 60=$CURRENTTIME; 6=$CURRENTPRICE; 14=$CUMQTY; 37=$ORDERID; 10=240;"
#    122
#    123	            echo $PARTIALFILL >>$LOGFILENAME
#    124
#    125	            ((x = x + 1))
#    126
#    127	            QTYREMAINING="$(echo $(($QTYREMAINING - $LASTTRDQTY)))"
#    128	            FILLTEST=0
#    129	            sleep 1
#    130
#    131	        else
#    132
#    133	            CURRENTTIME=$(date "+%Y-%m-%d-%T")
#    134	            CANCELORDERID="C_"$(echo $ORDERID)
#    135	            CANCELREQUEST="8=FIX4.4; 35=F; 34=$CLIENTSEQNUMBER; 49=$CLIENT; 56=$BROKER;  52=$CURRENTTIME; 41=$ORDERID; 55=$CURRENTSTOCK; 38=$QTY; 11=$CANCELORDERID; 60=$CURRENTTIME; 10=060;  "
#    136	            echo $CANCELREQUEST >>$LOGFILENAME
#    137	            let "CLIENTSEQNUMBER++"
#    138
#    139	            EXECID="exec"$(date "+%Y%m%d%H%M%S")
#    140	            CURRENTTIME=$(date "+%Y-%m-%d-%T")
#    141
#    142	            PENDINGCANCEL="8=FIX4.4; 35=8; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 55=$CURRENTSTOCK; 11=$CANCELORDERID; 31=0; 150=6; 39=6; 54=$SIDE; 44=$CURRENTPRICE; 17=$EXECID; 32=0; 41=$ORDERID; 38=$QTY; 60=$CURRENTTIME; 6=0.0; 14=$CUMQTY; 37=$ORDERID; 10=252; "
#    143	            echo $PENDINGCANCEL >>$LOGFILENAME
#    144	            let "BROKERSEQNUMBER++"
#    145
#    146	            EXECID="exec"$(date "+%Y%m%d%H%M%S")
#    147	            CURRENTTIME=$(date "+%Y-%m-%d-%T")
#    148
#    149	            CANCELACK="8=FIX4.4; 35=8; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 151=$QTYREMAINING; 55=$CURRENTSTOCK; 11=$CANCELORDERID; 31=0; 150=4; 39=4; 54=$SIDE; 17=$EXECID; 32=0;  41=$ORDERID; 38=$QTY; 60=$CURRENTTIME;  6=0.0; 14=$CUMQTY; 37=$ORDERID; 10=252;"
#    150
#    151	            echo $CANCELACK >>$LOGFILENAME
#    152	            let "BROKERSEQNUMBER++"
#    153	            FILLTEST=1
#    154	            x=$NUMBEROFPARTIALFILLS
#    155	            sleep 1
#    156
#    157	        fi
#    158
#    159	    done
#    160	    #if qty remaining is not = 0 then you need to do one more fill
#    161
#    162	    ((i = i + 1))
#    163	    sleep 1
#    164
#    165	    #Now we need to send out the fully filled message if we need it
#    166	    if [ $FILLTEST -eq 0 ]; then
#    167	        EXECID="exec"$(date "+%Y%m%d%H%M%S")
#    168	        CURRENTTIME=$(date "+%Y-%m-%d-%T")
#    169
#    170	        QTYREMAINING="$(echo $(($QTY - $CUMQTY)))"
#    171	        let "BROKERSEQNUMBER++"
#    172
#    173	        FULLYFILLED="8=FIX4.4; 35=8; 34=$BROKERSEQNUMBER; 49=$BROKER; 56=$CLIENT; 52=$CURRENTTIME; 55=$CURRENTSTOCK; 40=2; 11=$ORDERID; 31=$CURRENTPRICE; 150=2; 39=2; 54=$SIDE; 44=$CURRENTPRICE; 32=$QTYREMAINING; 17=$EXECID; 38=$QTY; 60=$CURRENTTIME; 6=$CURRENTPRICE; 14=$QTY; 37=$ORDERID; 10=246;"
#    174
#    175	        echo $FULLYFILLED >>$LOGFILENAME
#    176	    fi
#    177
#    178	done

# %% [markdown]
# Create newlogs from fixlog

# %%
# 3. Read the contents of the log file created using cat but direct it to a new file in your home directory named newlog.log
cat fixlog* > newlog.log

# 4. Create a directory named logs
mkdir logs

# 5. Move the newlog.log into the logs directory.
mv newlog.log logs/.

# 6. Cat the original log file you created again. This time, append its output to the newlog.log file you just moved.
cat fixlog* >> logs/newlog.log

# 7. Create a soft link named Daily to your newlog.log file in the logs directory.
ln -s newlog.log daily

ls -ltr
# Out:
# total 180
# -rwxr-xr-x 1 mheerspink mheerspink     0 Mar 25 08:50 '10 - cron.sh'
# -rwxr-xr-x 1 mheerspink mheerspink     0 Mar 25 08:50 '10 - cron.ipynb'
# -rwxr-xr-x 1 mheerspink mheerspink     0 Mar 25 08:50 '07 - editing-files.ipynb'
# -rwxr-xr-x 1 mheerspink mheerspink     0 Mar 25 08:50 '06 - disk-space.sh'
# -rwxr-xr-x 1 mheerspink mheerspink     0 Mar 25 08:50 '06 - disk-space.ipynb'
# -rwxr-xr-x 1 mheerspink mheerspink     0 Mar 25 08:50 '08 - a-deeper-dive-into-process.sh'
# -rwxr-xr-x 1 mheerspink mheerspink     0 Mar 25 08:50 '08 - a-deeper-dive-into-process.ipynb'
# -rwxr-xr-x 1 mheerspink mheerspink     0 Mar 25 08:50 '07 - editing-files.sh'
# -rwxr-xr-x 1 mheerspink mheerspink     0 Mar 25 08:50 '09 - advanced-commands.sh'
# -rwxr-xr-x 1 mheerspink mheerspink     0 Mar 25 08:50 '09 - advanced-commands.ipynb'
# -rwxr-xr-x 1 mheerspink mheerspink   974 Mar 25 08:50 '05 - health-of-a-server.sh'
# -rwxr-xr-x 1 mheerspink mheerspink 18469 Mar 25 08:50 '05 - health-of-a-server.ipynb'
# -rwxr-xr-x 1 mheerspink mheerspink  2051 Mar 25 09:20 '01 - basic-commands.sh'
# -rwxr-xr-x 1 mheerspink mheerspink  7311 Mar 25 09:44 '01 - basic-commands.ipynb'
# -rwxr-xr-x 1 mheerspink mheerspink 20735 Mar 25 11:20 '02 - files-and-filesystems.ipynb'
# drwxr-xr-x 2 mheerspink mheerspink  4096 Mar 25 11:26  ec2
# -rwxr-xr-x 1 mheerspink mheerspink  2111 Mar 25 11:43 '02 - files-and-filesystems.sh'
# -rwxr-xr-x 1 mheerspink mheerspink  3307 Mar 25 12:04 '03 - working-with-variables.sh'
# -rwxr-xr-x 1 mheerspink mheerspink  5596 Mar 25 12:05 '03 - working-with-variables.ipynb'
# -rwxr-xr-x 1 mheerspink mheerspink  6741 Mar 25 12:40  fixGenerator.sh
# -rw-r--r-- 1 mheerspink mheerspink 51397 Mar 25 12:44  fixlog.log
# -rwxr-xr-x 1 mheerspink mheerspink  3999 Mar 25 13:26 '04 - reading-files.sh'
# -rwxr-xr-x 1 mheerspink mheerspink 32748 Mar 25 13:29 '04 - reading-files.ipynb'
# drwxr-xr-x 2 mheerspink mheerspink  4096 Mar 25 13:33  logs
# lrwxrwxrwx 1 mheerspink mheerspink    10 Mar 25 13:33  daily -> newlog.log

# %% [markdown]
# Query the logs

# %%
# 11. Exit less and run a search using grep for all new order messages. Redirect the output to a le named newOrders.log in the logs directory.
grep 35=D fixlog* > logs/neworders.log

# 12. Copy the newOrders.log file from the logs directory to your home directory.
#cp logs/neworders.log ~/.
cp logs/neworders.log neworders.log

# 13. Run a command to find out how many lines are in the newOrders.log file.
echo 'Total Lines in newOrders.log:'
wc -l neworders.log

# 14. Run a command to pull out all of the messages with the instruction buy in x (you may need to look up the tag again) from the original log file and put them into a new log file in the logs directory named buyMessages.log
grep 54=1 fixlog* > logs/buymessages.log

# 15. Count how many lines are in that file.
echo $'\nTotal Lines in buyMessages.log:'
wc -l logs/buymessages.log

# 16. Count how many new orders are in the buyMessages.log.
echo $'\nNew Orders in buyMessages.log:'
grep 35=D logs/buymessages.log | wc -l

# 17. Create a new version of the log file named noNewOrders.log that has everything except new order messages in it and put it in the logs directory. 
grep -v 35=D fixlog* > logs/noneworders.log

# 18. Count how many words are in the noNewOrders.log. 
echo $'\nWord Count noNewOrders.log:'
wc -w logs/noneworders.log

# 19. Show the last 5 lines of the noNewOrders.log to the screen.
echo $'\nLast 5 lines of noNewOrders.log'
tail -n 5 logs/noneworders.log

# 20. Find all the messages relating to Apple in the original log file and show the first two lines to the screen. 
echo $'\nMessages relating to AAPL'
grep AAPL fixlog* | head -n 2
# Out:
# Total Lines in newOrders.log:
# 39 neworders.log
#
# Total Lines in buyMessages.log:
# 80 logs/buymessages.log
#
# New Orders in buyMessages.log:
# 20
#
# Word Count noNewOrders.log:
# 3888 logs/noneworders.log
#
# Last 5 lines of noNewOrders.log
# 8=FIX4.4; 35=8; 34=174; 49=MS; 56=MTHREE; 52=2022-03-25-12:44:41; 55=PEP; 40=2; 11=algo20220325124440; 31=45.43; 150=2; 39=2; 54=1; 44=45.43; 32=31389; 17=exec20220325124441; 38=31389; 60=2022-03-25-12:44:41; 6=45.43; 14=31389; 37=algo20220325124440; 10=246;
# 8=FIX4.4; 35=8; 34=175; 49=MS; 56=MTHREE; 52=2022-03-25-12:44:41; 55=; 40=2; 11=algo20220325124441; 31=; 150=0; 39=0; 54=2; 44=; 32=0; 17=exec20220325124441; 38=12556; 60=2022-03-25-12:44:41; 6=0; 14=0; 37=algo20220325124441; 10=200;
# 8=FIX4.4; 35=F; 34=114; 49=MTHREE; 56=MS; 52=2022-03-25-12:44:41; 41=algo20220325124441; 55=; 38=12556; 11=C_algo20220325124441; 60=2022-03-25-12:44:41; 10=060;
# 8=FIX4.4; 35=8; 34=175; 49=MS; 56=MTHREE; 52=2022-03-25-12:44:41; 55=; 11=C_algo20220325124441; 31=0; 150=6; 39=6; 54=2; 44=; 17=exec20220325124441; 32=0; 41=algo20220325124441; 38=12556; 60=2022-03-25-12:44:41; 6=0.0; 14=0; 37=algo20220325124441; 10=252;
# 8=FIX4.4; 35=8; 34=176; 49=MS; 56=MTHREE; 52=2022-03-25-12:44:41; 151=9417; 55=; 11=C_algo20220325124441; 31=0; 150=4; 39=4; 54=2; 17=exec20220325124441; 32=0; 41=algo20220325124441; 38=12556; 60=2022-03-25-12:44:41; 6=0.0; 14=0; 37=algo20220325124441; 10=252;
#
# Messages relating to AAPL
# 8=FIX4.4; 35=D; 34=52; 49=MTHREE; 56=MS; 52=2022-03-25-12:43:16; 55=AAPL; 40=2; 38=7670; 21=2; 11=algo20220325124316; 60=2022-03-25-12:43:16; 54=1; 44=1276.37; 10=0252;
# 8=FIX4.4; 35=8; 34=52; 49=MS; 56=MTHREE; 52=2022-03-25-12:43:16; 55=AAPL; 40=2; 11=algo20220325124316; 31=1276.37; 150=0; 39=0; 54=1; 44=1276.37; 32=0; 17=exec20220325124316; 38=7670; 60=2022-03-25-12:43:16; 6=0; 14=0; 37=algo20220325124316; 10=200;

# %% [markdown]
# More queries

# %%
# 21. Add a soft link named fix to your fixGenerator script.
ln -s fixgenerator.sh fix

# 22. Tail the log file created looking for new orders only in your tail command. (This will not actually cause any updates to the screen because the log file is not currently being updated.) 
# tail -f fixlog* | grep 35=D
echo $'Tail fixlog for new orders:'
tail fixlog* | grep 35=D

# 23. Create a new directory named superLogs
mkdir superlogs

# 24. Copy everything in the logs directory into the superLogs directory.
cp -r logs superlogs/.

# 25. Run a single grep command with an option on grep to count the number of messages for FB in the original log file that was created.
echo $'\nCount the number of messages for FB:'
grep -c FB fixlog*

# 26. Count the number of words in the original logfile. 
echo $'\nWord Count fixlog:'
wc -w fixlog*

# 27. Find the number of new order messages for Netflix in the original log file.
echo $'\nCount new messages for NFLX:'
grep 35=D fixlog* | grep NFLX | wc -l
# Out:
# Tail fixlog for new orders:
# 8=FIX4.4; 35=D; 34=113; 49=MTHREE; 56=MS; 52=2022-03-25-12:44:40; 55=PEP; 40=2; 38=31389; 21=2; 11=algo20220325124440; 60=2022-03-25-12:44:40; 54=1; 44=45.43; 10=0252;
# 8=FIX4.4; 35=D; 34=114; 49=MTHREE; 56=MS; 52=2022-03-25-12:44:41; 55=; 40=2; 38=12556; 21=2; 11=algo20220325124441; 60=2022-03-25-12:44:41; 54=2; 44=; 10=0252;
#
# Count the number of messages for FB:
# 5
#
# Word Count fixlog:
# 4473 fixlog.log
#
# Count new messages for NFLX:
# 1

# %% [markdown]
# Delete Generated Files

# %%
rm -rf daily fix logs neworders.log superlogs

echo $'\n-> generated files deleted\n'


pwd && ls
# Out:
# -> generated files deleted
#
# /home/mheerspink/exercises/bash_scripting_exercises/M1-Basic-Linux
# '01 - basic-commands.ipynb'          '07 - editing-files.ipynb'
# '01 - basic-commands.sh'             '07 - editing-files.sh'
# '02 - files-and-filesystems.ipynb'   '08 - a-deeper-dive-into-process.ipynb'
# '02 - files-and-filesystems.sh'      '08 - a-deeper-dive-into-process.sh'
# '03 - working-with-variables.ipynb'  '09 - advanced-commands.ipynb'
# '03 - working-with-variables.sh'     '09 - advanced-commands.sh'
# '04 - reading-files.ipynb'           '10 - cron.ipynb'
# '04 - reading-files.sh'              '10 - cron.sh'
# '05 - health-of-a-server.ipynb'       ec2
# '05 - health-of-a-server.sh'          fixGenerator.sh
# '06 - disk-space.ipynb'               fixlog.log
# '06 - disk-space.sh'
